# %%
import pandas as pd
import csv
import os
from sql_keys import username, password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from flask import Flask, jsonify

# %%
candy_hierarchy = "Resources/candy_hierarchy.csv"
candy_hierarchy_df = pd.read_csv(candy_hierarchy)
candy_hierarchy_df.head()
# Out:
#              CandyName  Total_Joy  Total_Meh  Total_Despair  NoResponse  \
# 0            100 Grand        873        755             85         747
# 1         3 Musketeers       1058        518            176         708
# 2  Nestle Butterfinger       1177        460            141         682
# 3             Chiclets        244        744            761         711
# 4                 Dots        410        657            664         729
#
#    TOTAL  Percent_Joy  Percent_Meh  Percent_Despair
# 0   2460     0.354878     0.306911         0.034553
# 1   2460     0.430081     0.210569         0.071545
# 2   2460     0.478455     0.186992         0.057317
# 3   2460     0.099187     0.302439         0.309350
# 4   2460     0.166667     0.267073         0.269919

# %%
candy_data= "Resources/candy-data.csv"
candy_data_df = pd.read_csv(candy_data)
candy_data_df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
candy_data_df = candy_data_df.rename(columns = {"competitorname":"CandyName"})
candy_data_df.head()
# Out:
#       CandyName  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0     100 Grand          1       0        1               0       0
# 1  3 Musketeers          1       0        0               0       1
# 2      One dime          0       0        0               0       0
# 3   One quarter          0       0        0               0       0
# 4     Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
candy_merge = candy_hierarchy_df.merge(candy_data_df, on= ["CandyName"], how="left" )
candy_merge = candy_merge [["CandyName", "Percent_Joy", "Percent_Meh", "Percent_Despair", "sugarpercent", "pricepercent", "winpercent"]]
candy_merge
# Out:
#                     CandyName  Percent_Joy  Percent_Meh  Percent_Despair  \
# 0                   100 Grand     0.354878     0.306911         0.034553
# 1                3 Musketeers     0.430081     0.210569         0.071545
# 2         Nestle Butterfinger     0.478455     0.186992         0.057317
# 3                    Chiclets     0.099187     0.302439         0.309350
# 4                        Dots     0.166667     0.267073         0.269919
# 5    Hershey's Milk Chocolate     0.364228     0.271138         0.091463
# 6            Hershey's Kisses     0.339024     0.295122         0.090244
# 7      Hershey's Special Dark     0.449187     0.206098         0.071138
# 8                Junior Mints     0.414634     0.201626         0.100000
# 9                     Kit Kat     0.588211     0.116667         0.021138
# 10                Laffy Taffy     0.182927     0.296341         0.221545
# 11                  Lemonhead     0.272358     0.280488         0.150407
# 12                 Mike & Ike     0.217073     0.263008         0.223577
# 13                  Milk Duds     0.356911     0.259756         0.101626
# 14                  Milky Way     0.481707     0.197154         0.041463
# 15                Mr Good Bar     0.348374     0.261382         0.089431
# 16                      Nerds     0.312602     0.247561         0.145935
# 17              Nestle Crunch     0.482927     0.191870         0.041463
# 18                Now & Later     0.146748     0.294715         0.226423
# 19                Peanut M&Ms     0.524797     0.153252         0.049187
# 20               Pixie Sticks     0.220732     0.263821         0.221951
# 21  Reese's Peanut Butter cup     0.608943     0.076423         0.038618
# 22             Reese's pieces     0.461789     0.189024         0.068293
# 23                     M & Ms     0.456098     0.239024         0.030488
# 24                       Rolo     0.467886     0.184959         0.056911
# 25          Skittles original     0.336992     0.245528         0.130488
# 26             Smarties candy     0.296341     0.236179         0.172764
# 27                   Snickers     0.568699     0.118699         0.032114
# 28            Sour Patch Kids     0.313008     0.179268         0.207724
# 29                  Starburst     0.346748     0.250000         0.121545
# 30               Swedish Fish     0.306504     0.220325         0.182520
# 31                       Twix     0.574390     0.116260         0.028862
#
#     sugarpercent  pricepercent  winpercent
# 0          0.732         0.860   66.971725
# 1          0.604         0.511   67.602936
# 2          0.604         0.767   70.735641
# 3          0.046         0.325   24.524988
# 4          0.732         0.511   42.272076
# 5          0.430         0.918   56.490501
# 6          0.127         0.093   55.375454
# 7          0.430         0.918   59.236122
# 8          0.197         0.511   57.219250
# 9          0.313         0.511   76.768600
# 10         0.220         0.116   41.389557
# 11         0.046         0.104   39.141056
# 12         0.872         0.325   46.411716
# 13         0.302         0.511   55.064072
# 14         0.604         0.651   73.099556
# 15         0.313         0.918   54.526451
# 16         0.848         0.325   55.354046
# 17         0.313         0.767   66.470680
# 18         0.220         0.325   39.446800
# 19         0.593         0.651   69.483788
# 20         0.093         0.023   37.722336
# 21         0.720         0.651   84.180290
# 22         0.406         0.651   73.434990
# 23         0.825         0.651   66.574585
# 24         0.860         0.860   65.716286
# 25         0.941         0.220   63.085140
# 26         0.267         0.116   45.995827
# 27         0.546         0.651   76.673782
# 28         0.069         0.116   59.863998
# 29         0.151         0.220   67.037628
# 30         0.604         0.755   54.861111
# 31         0.546         0.906   81.642914

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/ETL-Project')
Base= automap_base()
Base.prepare(engine, reflect = True)

# %%
engine.table_names()
# Out:
# ['Candy_data', 'Candy_hierarchy', 'Candy_merge']

# %%
candy_data_df.to_sql(name="Candy_data", con = engine, if_exists='append', index=False)

# %%
candy_hierarchy_df.to_sql(name="Candy_hierarchy", con= engine, if_exists='append', index=False)

# %%
candy_merge.to_sql(name="Candy_merge", con= engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from "Candy_data"', con=engine).head()
# Out:
#       CandyName  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0     100 Grand          1       0        1               0       0
# 1  3 Musketeers          1       0        0               0       1
# 2      One dime          0       0        0               0       0
# 3   One quarter          0       0        0               0       0
# 4     Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
pd.read_sql_query('select * from "Candy_hierarchy"', con=engine).head()
# Out:
#              CandyName  Total_Joy  Total_Meh  Total_Despair  NoResponse  \
# 0            100 Grand        873        755             85         747
# 1         3 Musketeers       1058        518            176         708
# 2  Nestle Butterfinger       1177        460            141         682
# 3             Chiclets        244        744            761         711
# 4                 Dots        410        657            664         729
#
#    TOTAL  Percent_Joy  Percent_Meh  Percent_Despair
# 0   2460     0.354878     0.306911         0.034553
# 1   2460     0.430081     0.210569         0.071545
# 2   2460     0.478455     0.186992         0.057317
# 3   2460     0.099187     0.302439         0.309350
# 4   2460     0.166667     0.267073         0.269919

# %%
pd.read_sql_query('select * from "Candy_merge"', con=engine).head()
# Out:
#              CandyName  Percent_Joy  Percent_Meh  Percent_Despair  \
# 0            100 Grand     0.354878     0.306911         0.034553
# 1         3 Musketeers     0.430081     0.210569         0.071545
# 2  Nestle Butterfinger     0.478455     0.186992         0.057317
# 3             Chiclets     0.099187     0.302439         0.309350
# 4                 Dots     0.166667     0.267073         0.269919
#
#    sugarpercent  pricepercent  winpercent
# 0         0.732         0.860   66.971725
# 1         0.604         0.511   67.602936
# 2         0.604         0.767   70.735641
# 3         0.046         0.325   24.524988
# 4         0.732         0.511   42.272076

# %%
Base.classes.keys()
data = Base.classes.Candy_data
hierarchy = Base.classes.Candy_hierarchy
merge = Base.classes.Candy_merge
session = Session(engine)
